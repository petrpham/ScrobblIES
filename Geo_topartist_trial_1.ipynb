# %% [markdown]
# # Last.fm Data-scrapping Project
#
# ## Get the 50 most favorite artist for given

# %%
from bs4 import BeautifulSoup
import requests
from lxml import html
import pandas as pd

# %% [markdown]
# We upload the list of countries defined by the ISO 3166-1 country names standard.

# %%
states = pd.read_csv("countries_cut_one.csv", sep =";", encoding='latin-1')
rqst_artist = 'https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&country=' + states + '&api_key=a96a3d9d79f3af63343555c8ba1451f6'
#print(rqst_artist.iloc[9]['COUNTRY'])
#print(states.iloc[9][0])

# %%
class Downloader():
    """
    A class designed to scrape the data based on a provided link
    """
    def __init__(self, name):
        """
        Initialization
        """
        print('Initialized downloader')
        self.name = name
        
        
                 
    def processTheLink(self,url):
        """
        Processing a given url
        """
        #self.
        self.url = url
        self.page = requests.get(url)
        self.soup = BeautifulSoup(self.page.text,'lxml')

# %%
#rqst_artist = pd.DataFrame(rqst_artist,states)
Countries = []
#Taiwan = Downloader( states.iloc[0][0]) 
#Taiwan.processTheLink(rqst_artist.iloc[0]['COUNTRY'])
#Countries.append(Taiwan)
#rqst_artist.iloc[2]['COUNTRY']
for k in range(len(rqst_artist)):
    new_state = Downloader(states.iloc[k][0])
    new_state.processTheLink(rqst_artist.iloc[k]['COUNTRY'])
    Countries.append(new_state)
    
#Taiwan.soup
# Out:
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader
# Initialized downloader

# %%
range(len(rqst_artist))
# Out:
# range(0, 236)

# %%
Countries[0].soup.find('name').text
# Out:
# 'Coldplay'

# %%
TOP_IN_EACH_COUNTRY = pd.DataFrame(columns=['Country', 'Top Artist'])
for k in range(len(rqst_artist)):    
    try:
        ADD = pd.DataFrame([[Countries[k].name,Countries[k].soup.find('name').text]], columns=['Country', 'Top Artist'] )
        TOP_IN_EACH_COUNTRY = TOP_IN_EACH_COUNTRY.append(ADD)        
    except:
        ADD = pd.DataFrame([[Countries[k].name,None]], columns=['Country', 'Top Artist'] )
        TOP_IN_EACH_COUNTRY= TOP_IN_EACH_COUNTRY.append(ADD)

# %%
TOP_IN_EACH_COUNTRY
# Out:
#                                               Country             Top Artist
# 0                                              Taiwan               Coldplay
# 0                                         Afghanistan                 The xx
# 0                                             Albania               Coldplay
# 0                                             Algeria               Coldplay
# 0                                      American Samoa            The Beatles
# 0                                             Andorra              Radiohead
# 0                                              Angola              Lady Gaga
# 0                                            Anguilla               Bon Iver
# 0                                          Antarctica                   None
# 0                                 Antigua and Barbuda              Lady Gaga
# 0                                           Argentina              Radiohead
# 0                                             Armenia              Radiohead
# 0                                               Aruba                Beyoncé
# 0                                           Australia              Radiohead
# 0                                             Austria                  Queen
# 0                                          Azerbaijan              Radiohead
# 0                                             Bahrain               Coldplay
# 0                                             Bahamas                  Drake
# 0                                          Bangladesh               Coldplay
# 0                                            Barbados                Rihanna
# 0                                             Belarus            Linkin Park
# 0                                             Belgium            David Bowie
# 0                                              Belize               Coldplay
# 0                                               Benin                 Eminem
# 0                                             Bermuda              Daft Punk
# 0                                              Bhutan           Lana Del Rey
# 0                                             Bolivia               Coldplay
# 0                              Bosnia and Herzegovina              Radiohead
# 0                                            Botswana                Rihanna
# 0                                              Brazil                Rihanna
# ..                                                ...                    ...
# 0                                            Thailand               Coldplay
# 0           The former Yugoslav Republic of Macedonia            David Bowie
# 0                                         Timor-Leste               Coldplay
# 0                                                Togo             The Weeknd
# 0                                             Tokelau                   None
# 0                                               Tonga            The Beatles
# 0                                 Trinidad and Tobago                Rihanna
# 0                                             Tunisia              Radiohead
# 0                                              Turkey              Radiohead
# 0                                        Turkmenistan                Nirvana
# 0                            Turks and Caicos Islands                   None
# 0                                              Tuvalu                   None
# 0                                              Uganda               Coldplay
# 0                                             Ukraine              Radiohead
# 0                                United Arab Emirates               Coldplay
# 0   United Kingdom of Great Britain and Northern I...            David Bowie
# 0                         United Republic of Tanzania                   None
# 0                United States Minor Outlying Islands                   None
# 0                        United States Virgin Islands                   None
# 0                            United States of America              Radiohead
# 0                                             Uruguay  Red Hot Chili Peppers
# 0                                          Uzbekistan            Linkin Park
# 0                                             Vanuatu              Radiohead
# 0                  Venezuela (Bolivarian Republic of)               Coldplay
# 0                                            Viet Nam               Coldplay
# 0                           Wallis and Futuna Islands                   None
# 0                                      Western Sahara                   None
# 0                                               Yemen                  Adele
# 0                                              Zambia             Kanye West
# 0                                            Zimbabwe          Justin Bieber
#
# [236 rows x 2 columns]

# %%
TOP_IN_EACH_COUNTRY.to_csv(path_or_buf='TOP.csv',sep=';',)
