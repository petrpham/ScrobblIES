# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from bs4 import BeautifulSoup

# %%
import pathlib

# %%
cwd = Path.cwd()
path_to_config = cwd / "Inputs/configpp.yml"

# %%
#Loading config file

import yaml
with open(path_to_config, 'r') as ymlfile:
    cfg = yaml.load(ymlfile)
# Out:
# C:\Users\petr.pham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   import sys

# %%
#API key extraction
apikey = cfg['lastfm'].get('apikey')

# %%
class LastFMDownloader: 
    '''
    Downloader class for collection of data and storage of results.
    '''
    def __init__(self, apikey, allowLog = True):
        
        '''
        Initilization of Downloader object. Storing objects from the webpage with self.qwe, self.rty and self.uio
        '''
        self.allowLog = allowLog
        self.apikey = apikey
        if self.allowLog:
            print('Downloader initialized.')
    
    def giveMeMyId(self, ID):
        self.id = ID
    
    def GetSoup(self, link):
        '''
        Returns soup in xml of from the given link in utf-8 encoding.
        '''
        self.link = link
        r = requests.get(link)
        r.encoding='UTF-8'
        self.soup = BeautifulSoup(r.text,'lxml')
    
    def GetJson(self, link):
        '''
        Returns JSON file for a given request
        '''
        self.linkToJson = link
        self.json = requests.get(link).json()
        
    
    def GetEmArtists(self, jsn):
        self.jsnPd = pd.read_json(json.dumps(jsn))
        self.topArtists = pd.DataFrame(columns=['Country', 'Rank', 'Artist', 'Scrobbles'])
        for i in range(1000):
            try:
                hlp = pd.DataFrame([[self.jsnPd.iloc[0,:][0]['country'], i+1, self.jsnPd.iloc[1,:][0][i]['name'],self.jsnPd.iloc[1,:][0][i]['listeners']]], columns=['Country', 'Rank', 'Artist', 'Scrobbles'])
                self.topArtists = self.topArtists.append(hlp)                
            except:
                pass
        return self.topArtists       
    
    def ProcessTheArtists(self, jsonFile):
        '''
        Process json files for artist info
        '''
        dfc = pd.read_json(json.dumps)
        
    
    def ParseSoupTag(self, tag):
        '''
        Returns a list of all lines with a certain tag.
        '''
        return self.soup.findAll(tag)
    
    def ParseSoupTagAttribute(self, tag, attribute, attribute_value):
        '''
        Returns a list of all lines with a certain tag given it's attribute.
        '''
        return self.soup.findAll(tag, {attribute, attribute_value})
    
    def SaveDfs(self): 
        '''
        Storing objects from the webpage as pandas DataFrame dictionary.
        '''
        dfs = {}
        dfs['Artists'] = self.artists
        dfs['Albums'] = self.albums
        dfs['Tracks'] = self.tracks
        self.resultsdf = dfs
        return self.resultsdf
    
    def getlinks(self):
        '''
        Returns all links.
        '''
        all_links = self.soup.find_all('a')
        for link in all_links:
             self.links = print(link.get('href'))
        return self.links

# %%
states = pd.read_csv("countries_cut_one.csv", sep =";", encoding='latin-1')
states.columns = ['CountryName', 'CountryNameUrl']

# %%
states = pd.read_csv("countries_cut_one.csv", sep =";", encoding='latin-1')

rqst_artist = 'https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&limit=1000&country=' + states + apikey

rqst_artist['Name'] = states['NAME']
rqst_artist['COUNTRY'][57]

states['NAME'].head()
# Out:
# 0            Taiwan
# 1       Afghanistan
# 2           Albania
# 3           Algeria
# 4    American Samoa
# Name: NAME, dtype: object

# %%
Countries = []

#for k in range(len(rqst_artist)):
for k in range(2):
    new_state = LastFMDownloader(k)    
    print(k) # knowing the stage
    new_state.giveMeMyId(k)
    new_state.GetJson(rqst_artist.iloc[k]['COUNTRY']) 
    print(rqst_artist.iloc[k]['COUNTRY']) # for check up
    Countries.append(new_state)
# Out:
# 0
# https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&limit=1000&country=Taiwan&api_key=a96a3d9d79f3af63343555c8ba1451f6&format=json
# Downloader initialized.
# 1
# https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&limit=1000&country=Afghanistan&api_key=a96a3d9d79f3af63343555c8ba1451f6&format=json

# %%
#for k in range(len(Countries)):
