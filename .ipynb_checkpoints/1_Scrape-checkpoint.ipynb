# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from bs4 import BeautifulSoup

# %%
import pathlib
import requests_cache
import time
from IPython.core.display import clear_output

# %%
cwd = Path.cwd()
path_to_config = cwd / "Inputs/configpp.yml"

# %%
#Loading config file

import yaml
with open(path_to_config, 'r') as ymlfile:
    config = yaml.load(ymlfile)
# Out:
# C:\Users\petr.pham\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
#API key extraction
apikey = config['lastfm'].get('apikey')

# %%
# Countries dataframe
countriesdf = pd.read_csv("countries_cut_one.csv", sep =";", encoding='latin-1')
countriesdf.columns = ['CountryName', 'CountryNameUrl']
countriesdf['CountryId'] = range(1, countriesdf.shape[0] + 1)
countriesdf = countriesdf[['CountryId', 'CountryName', 'CountryNameUrl']]

# %%
countriesdf = countriesdf.iloc[0:5, :]

# %%
countriesdf
# Out:
#      CountryId                                        CountryName  \
# 0            1                                             Taiwan
# 1            2                                        Afghanistan
# 2            3                                            Albania
# 3            4                                            Algeria
# 4            5                                     American Samoa
# 5            6                                            Andorra
# 6            7                                             Angola
# 7            8                                           Anguilla
# 8            9                                         Antarctica
# 9           10                                Antigua and Barbuda
# 10          11                                          Argentina
# 11          12                                            Armenia
# 12          13                                              Aruba
# 13          14                                          Australia
# 14          15                                            Austria
# 15          16                                         Azerbaijan
# 16          17                                            Bahrain
# 17          18                                            Bahamas
# 18          19                                         Bangladesh
# 19          20                                           Barbados
# 20          21                                            Belarus
# 21          22                                            Belgium
# 22          23                                             Belize
# 23          24                                              Benin
# 24          25                                            Bermuda
# 25          26                                             Bhutan
# 26          27                                            Bolivia
# 27          28                             Bosnia and Herzegovina
# 28          29                                           Botswana
# 29          30                                             Brazil
# ..         ...                                                ...
# 206        207                                           Thailand
# 207        208          The former Yugoslav Republic of Macedonia
# 208        209                                        Timor-Leste
# 209        210                                               Togo
# 210        211                                            Tokelau
# 211        212                                              Tonga
# 212        213                                Trinidad and Tobago
# 213        214                                            Tunisia
# 214        215                                             Turkey
# 215        216                                       Turkmenistan
# 216        217                           Turks and Caicos Islands
# 217        218                                             Tuvalu
# 218        219                                             Uganda
# 219        220                                            Ukraine
# 220        221                               United Arab Emirates
# 221        222  United Kingdom of Great Britain and Northern I...
# 222        223                        United Republic of Tanzania
# 223        224               United States Minor Outlying Islands
# 224        225                       United States Virgin Islands
# 225        226                           United States of America
# 226        227                                            Uruguay
# 227        228                                         Uzbekistan
# 228        229                                            Vanuatu
# 229        230                 Venezuela (Bolivarian Republic of)
# 230        231                                           Viet Nam
# 231        232                          Wallis and Futuna Islands
# 232        233                                     Western Sahara
# 233        234                                              Yemen
# 234        235                                             Zambia
# 235        236                                           Zimbabwe
#
#                            CountryNameUrl
# 0                                  Taiwan
# 1                             Afghanistan
# 2                                 Albania
# 3                                 Algeria
# 4                          American+Samoa
# 5                                 Andorra
# 6                                  Angola
# 7                                Anguilla
# 8                              Antarctica
# 9                     Antigua+and+Barbuda
# 10                              Argentina
# 11                                Armenia
# 12                                  Aruba
# 13                              Australia
# 14                                Austria
# 15                             Azerbaijan
# 16                                Bahrain
# 17                                Bahamas
# 18                             Bangladesh
# 19                               Barbados
# 20                                Belarus
# 21                                Belgium
# 22                                 Belize
# 23                                  Benin
# 24                                Bermuda
# 25                                 Bhutan
# 26                                Bolivia
# 27                 Bosnia+and+Herzegovina
# 28                               Botswana
# 29                                 Brazil
# ..                                    ...
# 206                              Thailand
# 207                             Macedonia
# 208                           Timor-Leste
# 209                                  Togo
# 210                               Tokelau
# 211                                 Tonga
# 212                   Trinidad+and+Tobago
# 213                               Tunisia
# 214                                Turkey
# 215                          Turkmenistan
# 216              Turks+and+Caicos+Islands
# 217                                Tuvalu
# 218                                Uganda
# 219                               Ukraine
# 220                  United+Arab+Emirates
# 221                        United+Kingdom
# 222           United+Republic+of+Tanzania
# 223  United+States+Minor+Outlying+Islands
# 224          United+States+Virgin+Islands
# 225                         United+States
# 226                               Uruguay
# 227                            Uzbekistan
# 228                               Vanuatu
# 229                             Venezuela
# 230                              Viet+Nam
# 231             Wallis+and+Futuna+Islands
# 232                        Western+Sahara
# 233                                 Yemen
# 234                                Zambia
# 235                              Zimbabwe
#
# [236 rows x 3 columns]

# %%
class LastFMDownloader: 
    '''
    Downloader class for collection of data and storage of results.
    '''
    
    def __init__(self, allowLog = True):
        '''
        Initilization of Downloader object. API key has to be provided. 
        '''
        self.allowLog = allowLog
        self.limit = 50
        self.jsonlist = []
        if self.allowLog:
            print('Downloader initialized.')
    
    def LoadCountryList(self, countryid = 0, countryname = 'Czech Republic'):
        '''
        Specifies country id and country names of GetDfGeo methods.
        '''
        self.countryid = countryid
        self.countryname = countryname
        
    def LoadArtistList(self, artist = '')
    
    def GetSoup(self, link):
        '''
        Returns soup in xml of from the given link in utf-8 encoding.
        '''
        self.link = link
        r = requests.get(link)
        r.encoding='UTF-8'
        self.soup = BeautifulSoup(r.text,'lxml')
    
    def RequestJson(self, links):
        '''
        Requests JSON files from given links and returns a list of JSON files stored in jsonlist attribute of the downloader.
        '''
        ## dodelat provide 1 link only
        requests_cache.install_cache() # storing previous requests
        number_of_files = len(links)
        self.jsonlist = []
        if len(links) >= 2:
            file = 1
            for link in links:
                print('Requesting file number {} out of {}'.format(file, number_of_files))
                clear_output(wait = True)
                jsonfile = requests.get(link).json()
                self.jsonlist.append(jsonfile)
                if not getattr(jsonfile, 'from_cache', False):
                    print('File has not been requested yet. Please wait half a second.')
                    time.sleep(0.5)
                file = file + 1
            clear_output(wait = True)
            print("All requested files are now available and stored in 'jsonlist' attribute.")
        
    
    def GetDfGeoTopArtists(self): 
        '''
        Provides data concerning most popular artists in given countries stored in a pandas dataframe. 
        LoadCountryList() method has to be called before-hand, in order to specify id of countries and country names.
        '''
        #self.DfGeoTopArtists = pd.DataFrame(columns=['CountryId', 'Country', 'Rank', 'Artist', 'ArtistId', 'Listeners'])
        #self.DfGeoTopTracks = pd.DataFrame(columns=['CountryId', 'Country', 'Rank', 'Track', 'Duration', 'Artist', 'ArtistId'])
        #self.DfArtistInfo = pd.DataFrame(columns=['ArtistId', 'Artist', 'Listeners', 'Scrobbles', 'Tag1', 'Tag2', 'Tag3', 'Tag4', 'Tag5'])
        ListGeoTopArtists = []
        for country in range(len(self.countryid)): # x number of countries range len countries
            for ranking in range(self.limit): # z number of ranks
                try:
                    row = []
                    rank = ranking + 1
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    artist = self.jsonlist[country]['topartists']['artist'][ranking]['name']
                    artistid = self.jsonlist[country]['topartists']['artist'][ranking]['mbid']
                    listeners = self.jsonlist[country]['topartists']['artist'][ranking]['listeners']
                    row.extend([countryid, countryname, rank, artist, artistid, listeners])
                    ListGeoTopArtists.append(row)
                except:
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    row = [countryid, countryname]
                    row.extend([None] * 4)
                    ListGeoTopArtists.append(row)
        self.DfGeoTopArtists = pd.DataFrame.from_records(ListGeoTopArtists)
        self.DfGeoTopArtists.columns = ['CountryId', 'Country', 'Rank', 'Artist', 'ArtistId', 'Listeners']
        print("Data concerning most popular artists in given countries are now available and stored in 'DfGeoTopArtists' attribute as a pandas dataframe.")
        return self.DfGeoTopArtists
    
    
    def GetDfGeoTopTracks(self): 
        '''
        Provides data concerning most popular tracks in given countries stored in a pandas dataframe. 
        LoadCountryList() method has to be called before-hand, in order to specify id of countries and country names.
        '''
        ListGeoTopTracks = []
        for country in range(len(self.countryid)): # x number of countries range len countries
            for ranking in range(self.limit): # z number of ranks
                try:
                    row = []
                    rank = ranking + 1
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    track = self.jsonlist[country]['tracks']['track'][ranking]['name']
                    duration = self.jsonlist[country]['tracks']['track'][ranking]['duration']
                    artist = self.jsonlist[country]['tracks']['track'][ranking]['artist']['name']
                    artistid = self.jsonlist[country]['tracks']['track'][ranking]['artist']['mbid']
                    row.extend([countryid, countryname, rank, track, duration, artist, artistid])
                    ListGeoTopTracks.append(row)
                except:
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    row = [countryid, countryname]
                    row.extend([None] * 5)
                    ListGeoTopTracks.append(row)
        self.DfGeoTopTracks = pd.DataFrame.from_records(ListGeoTopTracks)
        self.DfGeoTopTracks.columns = ['CountryId', 'Country', 'Rank', 'Track', 'Duration', 'Artist', 'ArtistId']
        print("Data concerning most popular artists in given countries are now available and stored in 'DfGeoTopTracks' attribute as a pandas dataframe.")
        return self.DfGeoTopTracks
    
    
    def GetDfArtistInfo(self): 
        '''
        Provides data concerning most popular artists in given countries stored in a pandas dataframe. 
        LoadCountryList() method has to be called before-hand, in order to specify id of countries and country names.
        '''
        #self.DfGeoTopArtists = pd.DataFrame(columns=['CountryId', 'Country', 'Rank', 'Artist', 'ArtistId', 'Listeners'])
        #self.DfGeoTopTracks = pd.DataFrame(columns=['CountryId', 'Country', 'Rank', 'Track', 'Duration', 'Artist', 'ArtistId'])
        #self.DfArtistInfo = pd.DataFrame(columns=['ArtistId', 'Artist', 'Listeners', 'Scrobbles', 'Tag1', 'Tag2', 'Tag3', 'Tag4', 'Tag5'])
        ListGeoTopArtists = []
        for country in range(len(self.countryid)): # x number of countries range len countries
            for ranking in range(self.limit): # z number of ranks
                try:
                    row = []
                    rank = ranking + 1
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    artist = self.jsonlist[country]['topartists']['artist'][ranking]['name']
                    artistid = self.jsonlist[country]['topartists']['artist'][ranking]['mbid']
                    listeners = self.jsonlist[country]['topartists']['artist'][ranking]['listeners']
                    row.extend([countryid, countryname, rank, artist, artistid, listeners])
                    ListGeoTopArtists.append(row)
                except:
                    countryid = self.countryid[country]
                    countryname = self.countryname[country]
                    row = [countryid, countryname]
                    row.extend([None] * 4)
                    ListGeoTopArtists.append(row)
        self.DfGeoTopArtists = pd.DataFrame.from_records(ListGeoTopArtists)
        self.DfGeoTopArtists.columns = ['CountryId', 'Country', 'Rank', 'Artist', 'ArtistId', 'Listeners']
        print("Data concerning most popular artists in given countries are now available and stored in 'DfGeoTopArtists' attribute as a pandas dataframe.")
        return self.DfGeoTopArtists
    

    def ProcessTheArtists(self, jsonFile):
        '''
        Process json files for artist info
        '''
        dfc = pd.read_json(json.dumps)
        
    
    def ParseSoupTag(self, tag):
        '''
        Returns a list of all lines with a certain tag.
        '''
        return self.soup.findAll(tag)
    
    def ParseSoupTagAttribute(self, tag, attribute, attribute_value):
        '''
        Returns a list of all lines with a certain tag given it's attribute.
        '''
        return self.soup.findAll(tag, {attribute, attribute_value})
    
    def SaveDfs(self): 
        '''
        Storing objects from the webpage as pandas DataFrame dictionary.
        '''
        dfs = {}
        dfs['Artists'] = self.artists
        dfs['Albums'] = self.albums
        dfs['Tracks'] = self.tracks
        self.resultsdf = dfs
        return self.resultsdf
    
    def getlinks(self):
        '''
        Returns all links.
        '''
        all_links = self.soup.find_all('a')
        for link in all_links:
             self.links = print(link.get('href'))
        return self.links

# %%
# GEO GET TOP TRACKS LIST
links = LastFMLink(apikey).GeoGetTop(countries = countriesdf['CountryNameUrl'], method = 'track')[55:57]

# %% [markdown]
# READING JSON
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
dwn = LastFMDownloader(apikey)
# Out:
# Downloader initialized.

# %%
dwn.LoadCountryList(countryid = countriesdf['CountryId'], countryname = countriesdf['CountryName'])

# %%
dwn.RequestJson(links = LastFMLink(apikey).GeoGetTop(countries = countriesdf['CountryNameUrl'], method = 'track'))
# Out:
# All requested files are now available and stored in 'jsonlist' attribute.

# %%
dwn.GetDfGeoTopTracks()
# Out:
# Data concerning most popular artists in given countries are now available and stored in 'DfGeoTopTracks' attribute as a pandas dataframe.
#        CountryId   Country  Rank                                       Track  \
# 0              1    Taiwan   1.0                                       Hello
# 1              1    Taiwan   2.0                                  Photograph
# 2              1    Taiwan   3.0                           Thinking Out Loud
# 3              1    Taiwan   4.0                                Shape of You
# 4              1    Taiwan   5.0                               The Scientist
# 5              1    Taiwan   6.0                          Can't Feel My Face
# 6              1    Taiwan   7.0                                      Yellow
# 7              1    Taiwan   8.0                               Cheap Thrills
# 8              1    Taiwan   9.0                                       Faded
# 9              1    Taiwan  10.0                            Someone Like You
# 10             1    Taiwan  11.0                           What Do You Mean?
# 11             1    Taiwan  12.0                               Love Yourself
# 12             1    Taiwan  13.0                     Adventure Of A Lifetime
# 13             1    Taiwan  14.0                          When We Were Young
# 14             1    Taiwan  15.0                               Hotline Bling
# 15             1    Taiwan  16.0                                       Sorry
# 16             1    Taiwan  17.0            Send My Love (To Your New Lover)
# 17             1    Taiwan  18.0                         Rolling in the Deep
# 18             1    Taiwan  19.0                                       Sugar
# 19             1    Taiwan  20.0               Lean On (feat. MØ & DJ Snake)
# 20             1    Taiwan  21.0                        Hymn for the Weekend
# 21             1    Taiwan  22.0                                      Closer
# 22             1    Taiwan  23.0                                     不為誰而作的歌
# 23             1    Taiwan  24.0                                     7 Years
# 24             1    Taiwan  25.0                                       Creep
# 25             1    Taiwan  26.0                                    Stitches
# 26             1    Taiwan  27.0                                Tenerife Sea
# 27             1    Taiwan  28.0  We Don't Talk Anymore (feat. Selena Gomez)
# 28             1    Taiwan  29.0               Sugar (feat. Francesco Yates)
# 29             1    Taiwan  30.0                                   The Hills
# ...          ...       ...   ...                                         ...
# 11770        236  Zimbabwe  21.0                            Do I Wanna Know?
# 11771        236  Zimbabwe  22.0                                Viva la Vida
# 11772        236  Zimbabwe  23.0                                  Wonderwall
# 11773        236  Zimbabwe  24.0                                       Intro
# 11774        236  Zimbabwe  25.0                                 Sex on Fire
# 11775        236  Zimbabwe  26.0                                 Skinny Love
# 11776        236  Zimbabwe  27.0                                  Poker Face
# 11777        236  Zimbabwe  28.0                                 Crystalised
# 11778        236  Zimbabwe  29.0                                     Fix You
# 11779        236  Zimbabwe  30.0                                      Yellow
# 11780        236  Zimbabwe  31.0                             Time to Pretend
# 11781        236  Zimbabwe  32.0                                      Royals
# 11782        236  Zimbabwe  33.0       I Bet You Look Good on the Dancefloor
# 11783        236  Zimbabwe  34.0                                  Chandelier
# 11784        236  Zimbabwe  35.0                            Someone Like You
# 11785        236  Zimbabwe  36.0                                Chasing Cars
# 11786        236  Zimbabwe  37.0                                Little Talks
# 11787        236  Zimbabwe  38.0                               Thank U, Next
# 11788        236  Zimbabwe  39.0                                    Uprising
# 11789        236  Zimbabwe  40.0                                   I'm Yours
# 11790        236  Zimbabwe  41.0                        No Tears Left To Cry
# 11791        236  Zimbabwe  42.0                           Take Me to Church
# 11792        236  Zimbabwe  43.0                                       Naïve
# 11793        236  Zimbabwe  44.0                                      A-Punk
# 11794        236  Zimbabwe  45.0                                     Pompeii
# 11795        236  Zimbabwe  46.0                          How to Save a Life
# 11796        236  Zimbabwe  47.0                             Dani California
# 11797        236  Zimbabwe  48.0                               Call Me Maybe
# 11798        236  Zimbabwe  49.0                                  Heartbeats
# 11799        236  Zimbabwe  50.0                                  Just Dance
#
#       Duration                 Artist                              ArtistId
# 0            0                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 1          258             Ed Sheeran  b8a7c51f-362c-4dcb-a259-bc6e0095f0a6
# 2          280             Ed Sheeran  b8a7c51f-362c-4dcb-a259-bc6e0095f0a6
# 3            0             Ed Sheeran  b8a7c51f-362c-4dcb-a259-bc6e0095f0a6
# 4          309               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 5            0             The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 6          267               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 7            0                    Sia  2f548675-008d-4332-876c-108b0c7ab9c5
# 8            0            Alan Walker
# 9          283                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 10           0          Justin Bieber  e0140a67-e4d1-4f13-8a01-364355bee46e
# 11           0          Justin Bieber  e0140a67-e4d1-4f13-8a01-364355bee46e
# 12           0               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 13           0                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 14           0                  Drake  b49b81cc-d5b7-4bdd-aadb-385df8de69a6
# 15           0          Justin Bieber  e0140a67-e4d1-4f13-8a01-364355bee46e
# 16           0                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 17         229                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 18         235               Maroon 5  0ab49580-c84f-44d4-875f-d83760ea2cfe
# 19           0            Major Lazer  75be165a-ad83-4d12-bd28-f589a15c479f
# 20           0               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 21           0       The Chainsmokers  91a81925-92f9-4fc9-b897-93cf01226282
# 22           0                    林俊傑  e5d8c705-8ea4-4820-b11d-fbf580d85ce4
# 23           0           Lukas Graham  124cec07-44f1-4a99-9aaa-96a5bb9ec0bd
# 24         239              Radiohead  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 25           0           Shawn Mendes  b7d92248-97e3-4450-8057-6fe06738f735
# 26         241             Ed Sheeran  b8a7c51f-362c-4dcb-a259-bc6e0095f0a6
# 27           0           Charlie Puth  525f1f1c-03f0-4bc8-8dfd-e7521f87631b
# 28           0           Robin Schulz  163218c2-9e0f-4d2d-aecb-ebbdef6aab70
# 29           0             The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# ...        ...                    ...                                   ...
# 11770      272         Arctic Monkeys  ada7a83c-e3e1-40f1-93f9-3e73dbc9298a
# 11771      241               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 11772      259                  Oasis  ecf9f3a3-35e9-4c58-acaa-e707fba45060
# 11773      127                 The xx  c5c2ea1c-4bde-4f4d-bd0b-47b200bf99d6
# 11774      222          Kings of Leon  6ffb8ea9-2370-44d8-b678-e9237bbd347b
# 11775      239               Bon Iver  437a0e49-c6ae-42f6-a6c1-84f25ed366bc
# 11776      239              Lady Gaga  650e7db6-b795-4eb5-a702-5ea2fc46c848
# 11777      201                 The xx  c5c2ea1c-4bde-4f4d-bd0b-47b200bf99d6
# 11778      294               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 11779      267               Coldplay  cc197bad-dc9c-440d-a5b5-d52ba2e14234
# 11780      261                   MGMT  c485632c-b784-4ee9-8ea1-c5fb365681fc
# 11781      223                  Lorde  8e494408-8620-4c6a-82c2-c2ca4a1e4f12
# 11782      172         Arctic Monkeys  ada7a83c-e3e1-40f1-93f9-3e73dbc9298a
# 11783      216                    Sia  2f548675-008d-4332-876c-108b0c7ab9c5
# 11784      283                  Adele  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493
# 11785        0            Snow Patrol  a66999a7-ae5c-460e-ba94-1a01143ae847
# 11786      266    Of Monsters and Men  9e103f85-7af7-41d7-b83b-49ba8f0c5abf
# 11787        0          Ariana Grande  f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
# 11788      302                   Muse  fd857293-5ab8-40de-b29e-55a69d4e4d0f
# 11789      242             Jason Mraz  82eb8936-7bf6-4577-8320-a2639465206d
# 11790        0          Ariana Grande  f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
# 11791        0                 Hozier  b4691384-50c3-4afd-9988-51d3ec5db65d
# 11792      204              The Kooks  f82f3a3e-29c2-42ca-b589-bc5dc210fa9e
# 11793      136        Vampire Weekend  af37c51c-0790-4a29-b995-456f98a6b8c9
# 11794      213               Bastille  fefe1208-5d8c-48a7-9b6c-2f5ffb62b063
# 11795      290               The Fray  2ddd167f-5b8a-4372-b350-6ad50493bac0
# 11796      283  Red Hot Chili Peppers  8bfac288-ccc5-448d-9573-c33ea2aa5c30
# 11797      194       Carly Rae Jepsen  09887aa7-226e-4ecc-9a0c-02d2ae5777e1
# 11798        0          José González  cd8c5019-5d75-4d5c-bc28-e1e26a7dd5c8
# 11799      277              Lady Gaga  650e7db6-b795-4eb5-a702-5ea2fc46c848
#
# [11800 rows x 7 columns]

# %%
dwn.DfGeoTopTracks.to_csv('geo_top_tracks.csv', encoding='utf-8-sig')

# %%
dwn.DfGeoTopArtists.to_csv('geo_top_artists.csv', encoding='utf-8-sig')

# %%
dwn.DfGeoTopTracks.Artist.unique()
# Out:
# array(['Adele', 'Ed Sheeran', 'Coldplay', 'The Weeknd', 'Sia',
#        'Alan Walker', 'Justin Bieber', 'Drake', 'Maroon 5', 'Major Lazer',
#        'The Chainsmokers', '林俊傑', 'Lukas Graham', 'Radiohead',
#        'Shawn Mendes', 'Charlie Puth', 'Robin Schulz', 'Mark Ronson',
#        'The xx', 'Ellie Goulding', 'José González', 'Zara Larsson',
#        'James Bay', 'Sam Smith', 'Iron & Wine', 'Mike Posner',
#        'Vance Joy', 'Passenger', 'Twenty One Pilots', 'Oasis', 'M83',
#        'alt-J', 'Nirvana', 'Simon & Garfunkel', 'Lynyrd Skynyrd',
#        'Portugal. The Man', 'Creedence Clearwater Revival', 'Zero 7',
#        'Metallica', 'Blind Melon', 'The Proclaimers', 'Bonobo', 'Air',
#        'Deftones', 'Boards of Canada', 'Glass Animals', 'The Jackson 5',
#        'Ludovico Einaudi', 'Petit biscuit', 'Hot Chocolate',
#        'The Four Tops', 'Helios', 'Sam Cooke', 'The Contours', 'Kiasmos',
#        'Agnes Obel', 'Little People', 'The Drifters', 'Stevie Wonder',
#        'Com Truise', 'Blockhead', "Patrick O'Hearn", 'Forest Swords',
#        'Yppah', 'Astrud Gilberto', 'Tame Impala', 'Imagine Dragons',
#        'Gorillaz', 'Pixies', 'Massive Attack', 'Portishead',
#        'The White Stripes', 'The Verve', 'Kendrick Lamar',
#        'Arctic Monkeys', 'Joy Division', 'Hozier', 'R.E.M.', 'Bon Iver',
#        'The Cure', 'The Cinematic Orchestra', 'Kings of Leon',
#        'Red Hot Chili Peppers', 'MGMT', 'Franz Ferdinand',
#        'Florence + the Machine', 'Black Sabbath', 'The Strokes',
#        'Dire Straits', 'AC/DC', 'Motörhead', 'Survivor', 'Miles Davis',
#        'Linkin Park', 'Foo Fighters', "Guns N' Roses", 'Michael Jackson',
#        'Aerosmith', 'The Smashing Pumpkins', 'Queen', 'Muse',
#        'Rage Against the Machine', 'a-ha', 'Toto', 'Led Zeppelin',
#        'Queens of the Stone Age', 'Lorde', 'The Shins', 'Kanye West',
#        'Fleet Foxes', 'Ariana Grande', 'Lana Del Rey', 'Iggy Pop',
#        'The Rolling Stones', 'Kurt Vile', 'System of a Down',
#        'Supergrass', 'David Bowie', 'Amy Winehouse', 'Band of Horses',
#        'CHVRCHES', 'Beach House', 'Stealers Wheel',
#        'Unknown Mortal Orchestra', 'Arcade Fire', 'Jamie xx', 'Bastille',
#        'OneRepublic', 'John Legend', 'Bruno Mars', 'DNCE',
#        'Calvin Harris', 'Jason Derülo', 'Jason Mraz', 'Clean Bandit',
#        'Rihanna', 'Al Green', 'Justin Timberlake', 'Fifth Harmony',
#        'Lily Allen', 'The Killers', 'blink-182', 'Tracy Chapman',
#        'Paul Simon', 'Selena Gomez', 'One Direction', 'Niall Horan',
#        'Sheryl Crow', 'Sam Feldt', 'Carly Rae Jepsen',
#        'Pharrell Williams', 'Mariah Carey', 'Grimes', 'Jack Johnson',
#        'Ke$ha', 'Taylor Swift', 'Miley Cyrus', 'Post Malone',
#        'Childish Gambino', 'Sublime', 'Eminem', 'Elliott Smith',
#        'Natalie Imbruglia', None, 'Dua Lipa', 'Alessia Cara', 'Lady Gaga',
#        'Macklemore & Ryan Lewis', 'Disclosure', 'The Notorious B.I.G.',
#        'Zayn', 'TLC', 'Gustavo Cerati', 'Blur', 'Babasónicos',
#        'Luis Alberto Spinetta', 'Soundgarden', 'Lou Reed', 'Pink Floyd',
#        'Kaleo', 'Johnny Cash', 'The Cranberries', 'Cigarettes After Sex',
#        'Foster the People', 'Hailee Steinfeld', 'Walk the Moon', 'ABBA',
#        'Van Morrison', 'Simple Minds', 'Lil Nas X', 'Belinda Carlisle',
#        'Buena Vista Social Club', 'Kim Carnes', 'Adam Lambert',
#        'Jamiroquai', 'Dolly Parton', 'Frank Ocean', 'Alice Deejay',
#        'Snow Patrol', 'Of Monsters and Men', 'Two Door Cinema Club',
#        'Tears for Fears', 'Flume', 'Crowded House', 'The Temper Trap',
#        'Bilderbuch', 'Journey', 'Wanda', 'Seiler und Speer', 'Green Day',
#        'The Black Keys', 'Duke Dumont', 'No Doubt', 'Gotye', 'Keane',
#        'Daft Punk', 'Gnarls Barkley', 'Bon Jovi', 'Fetty Wap', 'Kiiara',
#        'Bryson Tiller', 'Azealia Banks', 'Solange', 'Beyoncé', 'Avicii',
#        'Scorpions', 'U2', 'Evanescence', 'Prince', 'Missy Elliott',
#        'Cardi B', "Destiny's Child", 'Blackstreet', 'Desiigner',
#        'Mary J. Blige', 'The Lumineers', 'OutKast', 'Dr. Dre',
#        'Three Days Grace', 'Сплин', 'Depeche Mode', 'The War on Drugs',
#        'Bazart', 'Jimi Hendrix', 'Edward Sharpe & The Magnetic Zeros',
#        'Fleetwood Mac', 'Rise Against', 'The Doors', 'James Blunt',
#        'Bruce Springsteen', 'LIL UZI VERT', 'John Mayer', 'Seal',
#        'James Arthur', 'Future', 'Rhye', 'Ace of Base',
#        'Bob Marley & The Wailers', 'Khalid', 'Etta James',
#        'Andy Williams', 'Earth, Wind & Fire', 'Wham!', 'Michael Bublé',
#        'Bobby Helms', 'Nat King Cole', 'Billie Eilish',
#        'Jefferson Airplane', 'Meghan Trainor', 'Bing Crosby',
#        'Elvis Presley', 'Phoenix', 'Paramore', 'The Knife', 'The 1975',
#        'The Postal Service', 'Duffy', 'The Ting Tings',
#        'The Naked and Famous', 'FKA twigs', 'LCD Soundsystem',
#        'Vampire Weekend', 'Regina Spektor', 'Crystal Castles',
#        'Audioslave', 'Stone Temple Pilots', 'Goo Goo Dolls',
#        'Andrés Calamaro', 'Alice in Chains', 'Kiesza', 'Julia Michaels',
#        'The Script', 'Old Crow Medicine Show', 'Nils Frahm',
#        'The American Dollar', 'Rizzle Kicks', 'Aaliyah', 'Awolnation',
#        'Britney Spears', 'Birdy', 'George Ezra', 'Alicia Keys',
#        'Little Mix', 'Rachel Platten', 'Disturbed', 'Papa Roach', 'Korn',
#        'Rammstein', 'Slipknot', 'Death Cab for Cutie', 'The Fray',
#        'Jimmy Eat World', 'David Guetta', 'Katy Perry', 'Bright Eyes',
#        'Damien Rice', 'Imogen Heap', 'Klaxons', 'The Beatles',
#        'A Day to Remember', 'Buffalo Springfield', 'Tyler, the Creator',
#        'Electric Light Orchestra', 'The Mamas & the Papas', 'Neil Young',
#        'The National', 'Aretha Franklin', 'The Beach Boys',
#        'The Velvet Underground', 'Deep Purple', 'Janis Joplin',
#        'Derek and the Dominos', 'The Jimi Hendrix Experience',
#        'Marvin Gaye', 'A Tribe Called Quest', 'Maxwell', 'Grizzly Bear',
#        'Sufjan Stevens', 'James Blake', 'Aphex Twin', 'Bibio',
#        'Dusty Springfield', 'M.I.A.', 'Kelly Clarkson', 'Modest Mouse',
#        'Weezer', 'Eagles', 'Counting Crows', 'Bill Withers', 'Soft Cell',
#        'The Stranglers', 'Ben Howard', 'Fugees', 'Leonard Cohen',
#        'The Presidents of the United States of America',
#        'The Doobie Brothers', 'Frankie Goes to Hollywood', 'Joe Cocker',
#        'Jonas Blue', 'Tool', 'Los Prisioneros', 'Los Tres', 'Pearl Jam',
#        'Mumford & Sons', 'Capital Cities', 'Aterciopelados',
#        'Bomba Estéreo', 'Mazzy Star', 'A Great Big World', 'Mario',
#        'Urge Overkill', 'The Righteous Brothers', 'Daniel Caesar',
#        'Sarah McLachlan', 'Nicki Minaj', 'The Dave Brubeck Quartet',
#        'Kodak Black', 'Ciara', 'Eric Clapton', 'Phil Collins',
#        'Soulja Boy', 'Ava Max', 'Bad Bunny', 'Ray LaMontagne',
#        'John Lee Hooker', 'Janelle Monáe', 'Migos', 'Janet Jackson',
#        'Nicky Jam', 'Incubus', 'Marilyn Manson', 'Manu Chao', 'Epic45',
#        'Passion Pit', 'Smash Mouth', 'The Animals', 'Beck',
#        'The Offspring', 'Wiz Khalifa', 'Stromae', 'Felix Jaehn',
#        'Lauryn Hill', 'Booba', 'Alpha Blondy', 'Lucky Dube', 'Papa Wemba',
#        "Kassav'", 'French Montana', 'MØ', 'Phlake', 'José Feliciano',
#        'Drengene fra Angora', 'Chris Rea', 'Mads Langer', 'Shu-bi-dua',
#        'Tony Bennett', 'MC Einar', 'Mel & Kim', 'Rasmus Seebach',
#        'Boney M.', 'Blak', 'Supertramp', 'The Neighbourhood',
#        'Empire of the Sun', 'Kavinsky', 'BØRNS', 'Atlas Genius',
#        'The Wombats', 'The Strumbellas', 'Oh Wonder', 'St. Lucia',
#        'Lifehouse', 'Lany', 'Daya', 'Ra Ra Riot', 'Léon', 'Who Is Fancy',
#        'Jarabe de Palo', 'Soda Stereo', 'Tired Pony', 'Lior',
#        'William Fitzsimmons', 'Sarah Jaffe', 'Ewert and the Two Dragons',
#        'Interpol', 'America', 'George Michael', 'Haddaway',
#        "Sinéad O'Connor", 'The Stone Roses', 'Elton John', '10cc',
#        'The Pogues', 'The Deli', "Youssou N'Dour", 'Wu-Tang Clan',
#        'Large Professor', 'Blue Öyster Cult', 'Bryan Adams',
#        'Backstreet Boys', 'Cher', "Rag'n'Bone Man", 'Kenny Loggins',
#        'Eivør Pálsdóttir', 'Marius Ziska', 'The Police', 'Boston',
#        'Whitney Houston', 'Becky G', 'Dave Brubeck', 'Omi',
#        'Royal Headache', 'Sanni', 'JVG', "Bomfunk MC's",
#        'Leevi and the Leavings', 'Ghost', 'Haloo Helsinki!',
#        'J. Karjalainen', 'Zen Café', 'Antti Tuisku', 'Egotrippi', 'Alma',
#        'Pariisin Kevät', 'Eppu Normaali', 'Jain', 'Metronomy',
#        'Nina Simone', 'Norah Jones', '50 Cent', 'UB40', 'Noir Désir',
#        'Orelsan', 'Kalash', 'Broken Back', 'Ben E. King', 'Karin Borg',
#        'Otis Redding', 'Aloe Blacc', 'The Temptations', 'Yiruma',
#        'Bobby McFerrin', 'The Smiths', 'Yeah Yeah Yeahs', 'Moby',
#        'Moderat', 'AnnenMayKantereit', '3 Doors Down', 'K.I.Z.',
#        'Tina Turner', 'Years & Years', 'Band Aid', 'Camila Cabello',
#        'Madonna', 'Kylie Minogue', 'Echo & the Bunnymen', 'Jon Hopkins',
#        'Diana Krall', 'Rocazino', 'Simon Lynge', "Plain White T's",
#        'Train', 'Spin Doctors', 'Crazy Town', 'Black Eyed Peas', 'Kygo',
#        'Jeff Buckley', 'Jet', '*NSYNC', 'Leona Lewis', 'Lizzo',
#        'Third Eye Blind', 'Héroes del Silencio', 'Brenda Lee',
#        'Eartha Kitt', 'MUD', 'Panic! at the Disco', 'J. Cole',
#        'Young Thug', 'Y2K', 'Travi$ Scott', 'Chris Brown', 'Lil Baby',
#        'Chance the Rapper', 'A Boogie Wit da Hoodie', 'Ella Mai', 'Tycho',
#        'Gnash', 'Sylvan Esso', 'Toni Braxton', 'Mount Kimbie',
#        'Joel Adams', 'Milo Greene', 'Xavier Rudd', 'Melvv', 'Jaffna',
#        'Parson James', 'Foals', 'Hjálmar', 'Sigur Rós', 'JóiPé',
#        'Porcupine Tree', 'Payung Teduh', 'Float', "MALIQ & D'Essentials",
#        'Sixpence None the Richer', 'Sheila On 7', 'Dewa 19',
#        'Efek Rumah Kaca', 'Adhitia Sofyan', 'Adam Levine', 'Europe',
#        'The Dandy Warhols', 'Cyndi Lauper', 'Kate Bush', 'Calcutta',
#        'Damian Marley', 'Usher', 'Koffee', 'Protoje', 'スピッツ', 'Suchmos',
#        'サカナクション', '宇多田ヒカル', 'ASIAN KUNG-FU GENERATION', 'くるり', '椎名林檎',
#        'Perfume', '東京事変', '松任谷由実', 'The Kooks', 'The Ronettes', 'Fairuz',
#        'Kansas', 'Limp Bizkit', 'Static-X', 'Кино', 'The Cardigans',
#        'Cream', 'Justice', "Mashrou' Leila", 'Babyface', 'Chanté Moore',
#        'Coolio', 'Judas Priest', 'Marshmello', 'Sarah Jarosz',
#        'Macy Gray', 'Charli XCX', '5 Seconds of Summer', 'ScHoolboy Q',
#        'Run the Jewels', 'Rixton', 'Big Sean', 'Jay-Z', 'Anderson .Paak',
#        'Joey Bada$$', 'Hoobastank', 'Vanessa Carlton', 'Yuna',
#        'Bob Dylan', 'Feist', 'Magic!', 'The Band', 'Mos Def',
#        'Erykah Badu', 'DJ Snake', 'Kungs', 'Nickelback', 'Milky Chance',
#        'Halsey', 'Flo Rida', 'Warren G', 'Nelly', 'Demi Lovato',
#        'Emeli Sandé', 'Free', 'R. Kelly', 'Natalia Lafourcade',
#        'Café Tacvba', 'Caifanes', 'Laura Marling', 'Bloc Party',
#        'Peter Bjorn and John', 'Nujabes', 'Corinne Bailey Rae',
#        'Bloodhound Gang', 'Burial', 'Silversun Pickups',
#        'My Bloody Valentine', 'Rick Astley', 'Slowdive', 'Live',
#        'Breaking Benjamin', 'NF', 'My Chemical Romance', 'Bipul Chettri',
#        'Lamb of God', 'De Jeugd van Tegenwoordig', 'Billy Joel',
#        'London Grammar', 'C2C', 'Mary Juane Clair', 'RUNTOWN',
#        'Burna Boy', 'Wizkid', 'Tekno', 'Davido', 'Mr Eazi', 'teni',
#        'Kiss', 'Sex Pistols', 'The Clash', 'The Runaways', 'The Cars',
#        'Misfits', 'NOFX', 'Hall & Oates', 'A$AP Rocky', 'Sampha',
#        'Wild Nothing', 'Miguel', 'Deerhunter', 'Maria Mena',
#        'Susanne Sundfør', 'Highasakite', 'Aurora', 'Karpe Diem', 'Sigrid',
#        'Astrid S', 'Lemâitre', 'Röyksopp', 'Daughter', 'Hans Zimmer',
#        'Junoon', 'Jay-Z & Kanye West', 'P!nk', 'Maxi Priest',
#        'Up Dharma Down', 'Troye Sivan', 'Dawid Podsiadło',
#        'Ornatos Violeta', 'The Prodigy', 'Nas', 'Michael Kiwanuka', 'Nao',
#        'Sauti Sol', 'Owl City', 'X Ambassadors', 'Møme', 'LP',
#        'George Harrison', 'Sonic Youth', 'Carole King', 'J Dilla',
#        'Steely Dan', 'Berlin', 'Explosions in the Sky', 'Kid Cudi',
#        'J Balvin', 'Duke Ellington', 'Charles Mingus', 'Herbie Hancock',
#        'McCoy Tyner', 'Odesza', 'Martin Garrix', 'Extreme', 'Placebo',
#        'Black Rebel Motorcycle Club', 'Hole', 'Suzanne Vega', 'CocoRosie',
#        'Bat for Lashes', 'Joni Mitchell', 'Bikini Kill', 'L7',
#        'PJ Harvey', 'Garbage', 'Dwayne Johnson', 'The Kills', 'Björk',
#        'The Dresden Dolls', 'Joanna Newsom', 'Goldfrapp', 'Paula Cole',
#        'Dizzee Rascal', 'Aimee Mann', 'Beth Gibbons & Rustin Man',
#        'Royal Blood', 'Nathaniel Rateliff & the Night Sweats',
#        'Stone Sour', 'New Order', 'Vetusta Morla', 'Christina Perri',
#        'Gwen Stefani', 'Lewis Capaldi', 'Benjamin Francis Leftwich',
#        'MATOMA', 'Chrome Sparks', 'Baauer', 'LeAnn Rimes', 'Otto Knows',
#        'Naughty By Nature', 'Hayden James', 'Kindness', 'Listenbee',
#        'John Newman', 'Kaytranada', 'FKJ', 'Shift K3Y', 'Hermitude',
#        '20syl', 'Galimatias', 'Timbaland', 'Clubfeet', 'Set Mo', 'Kaasi',
#        'Bob Marley', 'DJ Snake, AlunaGeorge', 'Nora En Pure', 'Kid Ink',
#        'AlunaGeorge', 'Pev & Kowton', 'Tom Misch', 'Bunji Garlin',
#        'Goodluck', 'Cosmic Quest', 'Second City', 'Morgan Page',
#        'Tinashe', 'Sage the Gemini', 'Delroy Edwards', 'Laleh', 'Kent',
#        'Robyn', 'Håkan Hellström', 'Veronica Maggio', 'Adolphson & Falk',
#        'Broder Daniel', 'Miriam Bryant', 'Oskar Linnros', 'Opeth',
#        'Anathema', 'Draconian', 'Sting', 'Louis Armstrong',
#        'Fall Out Boy', 'Rob Zombie', 'Tove Lo', 'Sum 41', 'Crossfade',
#        'Creed', 'Foreigner', 'Richard Marx', 'The Pretenders',
#        'Bryan Adams, Rod Stewart & Sting', 'Omarion', 'Animal Collective',
#        'Lykke Li', 'Quantic', 'Hooverphonic', 'Mor ve Ötesi',
#        'Yann Tiersen', 'MFÖ', 'Büyük Ev Ablukada', 'Barış Manço',
#        'The Chemical Brothers', 'Modjo', 'Archive', 'Ill Niño',
#        'Animal Джаz', 'монеточка', 'Би-2', 'Spineshank', 'Noize MC',
#        'The Human League', 'Spandau Ballet', '2Pac', 'Ms. Lauryn Hill',
#        'India.Arie', 'Diamond Platnumz', 'Washed Out', 'Talking Heads',
#        'Alanis Morissette', 'Tori Amos', 'Scissor Sisters',
#        'Donna Summer', 'Technotronic', 'Katrina and the Waves', 'BTS'],
#       dtype=object)

# %%
pd.read_json(json.dumps(dwn.jsonlist)).iloc[1,0]['@attr']['country']
# Out:
# 'Curaçao'

# %%
# for loop x in range len countries - vezmu vsechny zeme
# for loop z in range(self.limit) - vezmu top XX artistu
x = 2
z = 1
pd.read_json(json.dumps(dwn.jsonlist)).iloc[x,0]['artist'][z]['name']
# Out:
# 'Queen'

# %%
pd.read_json(json.dumps(dwn.jsonlist)).iloc[x,0]['artist'][z]['mbid']
# Out:
# '420ca290-76c5-41af-999e-564d7c71f1a7'

# %%
pd.read_json(json.dumps(dwn.jsonlist)).iloc[x,0]['artist'][z]['listeners']
# Out:
# '4139663'

# %%
pd.read_json(json.dumps(dwn.jsonlist))
# Out:
#                                           topartists
# 0  {'artist': [{'name': 'The Beatles', 'listeners...
# 1  {'artist': [], '@attr': {'country': 'Curaçao',...
# 2  {'artist': [{'name': 'Coldplay', 'listeners': ...

# %%
ij = pd.read_json(json.dumps(dwn.jsonlist)).iloc[x,0]['artist'][z]

# %%
ij['name']
# Out:
# 'Queen'

# %%
topArtists = pd.DataFrame(columns=['CountryId', 'Country', 'Rank', 'Artist', 'ArtistId', 'Listeners'])
table = []
for z in dwn.jsonlist:           
    try:
        row = []
        artist = dwn.jsonlist[x]['topartists']['artist'][z]['name']
        rank = dwn.jsonlist[x]['topartists']['artist'][z]['mbid']
        listeners = dwn.jsonlist[x]['topartists']['artist'][z]['listeners']
        row.append(rank, artist, listeners)
        table.append(row)
    except:
        pass
print(table)
# Out:
# []

# %%
table = []
z = 1
## geo top tracks
ListGeoTopArtists = []
for country in range(3): # x number of countries range len countries
    print(dwn.countryid[country])
    print(dwn.countryname[country])
    for ranking in range(dwn.limit): # z number of ranks
        try:
            row = []
            rank = ranking + 1
            countryid = dwn.countryid[country]
            countryname = dwn.countryname[country]
            artist = dwn.jsonlist[country]['topartists']['artist'][ranking]['name']
            artistid = dwn.jsonlist[country]['topartists']['artist'][ranking]['mbid']
            listeners = dwn.jsonlist[country]['topartists']['artist'][ranking]['listeners']
            row.extend([countryid, countryname, rank, artist, artistid, listeners])
            ListGeoTopArtists.append(row)
        except:
            row = [None] * 6
            ListGeoTopArtists.append(row)
#return self. = pd.DataFrame.from_records(ListGeoTopArtists)
    #ListGeoTopArtists.append(ListCountryTopArtists)
#print(ListCountryTopArtists)
#print(ListGeoTopArtists)
# Out:
# 1
# Taiwan
# 2
# Afghanistan
# 3
# Albania

# %%
ListGeoTopArtists
# Out:
# [[1,
#   'Taiwan',
#   1,
#   'The Beatles',
#   'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#   '3783733'],
#  [1,
#   'Taiwan',
#   2,
#   'Nirvana',
#   '9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6',
#   '4362266'],
#  [1,
#   'Taiwan',
#   3,
#   'Daft Punk',
#   '056e4f3e-d505-4dad-8ec1-d04f521cbb56',
#   '3864620'],
#  [1, 'Taiwan', 4, 'U2', 'a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432', '3547039'],
#  [1, 'Taiwan', 5, 'Sia', '2f548675-008d-4332-876c-108b0c7ab9c5', '2214644'],
#  [1,
#   'Taiwan',
#   6,
#   'Fleetwood Mac',
#   'bd13909f-1c29-4c27-a874-d4aaf27c5b1a',
#   '2246300'],
#  [1,
#   'Taiwan',
#   7,
#   'Justin Timberlake',
#   '596ffa74-3d08-44ef-b113-765d43d12738',
#   '2894937'],
#  [1,
#   'Taiwan',
#   8,
#   'Elton John',
#   'b83bc61f-8451-4a5d-8b8e-7e9ed295e822',
#   '2612368'],
#  [1,
#   'Taiwan',
#   9,
#   'The Police',
#   '9e0e2b01-41db-4008-bd8b-988977d6019a',
#   '2349324'],
#  [1,
#   'Taiwan',
#   10,
#   'Jason Derülo',
#   '6de0f914-3e60-4418-be3b-42e0feb6eb4d',
#   '1932949'],
#  [1, 'Taiwan', 11, 'Cardi B', '', '402655'],
#  [1,
#   'Taiwan',
#   12,
#   'Arctic Monkeys',
#   'ada7a83c-e3e1-40f1-93f9-3e73dbc9298a',
#   '3594730'],
#  [1,
#   'Taiwan',
#   13,
#   'Coldplay',
#   'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#   '5487151'],
#  [1,
#   'Taiwan',
#   14,
#   'Kanye West',
#   '164f0d73-1234-4e2c-8743-d77bf2191051',
#   '4524008'],
#  [1,
#   'Taiwan',
#   15,
#   'Lana Del Rey',
#   'b7539c32-53e7-4908-bda3-81449c367da6',
#   '2017109'],
#  [1,
#   'Taiwan',
#   16,
#   'Red Hot Chili Peppers',
#   '8bfac288-ccc5-448d-9573-c33ea2aa5c30',
#   '4704723'],
#  [1,
#   'Taiwan',
#   17,
#   'Eminem',
#   'b95ce3ff-3d05-4e87-9e01-c97b66af13d4',
#   '4624847'],
#  [1,
#   'Taiwan',
#   18,
#   'Ariana Grande',
#   'f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387',
#   '1239294'],
#  [1,
#   'Taiwan',
#   19,
#   'The Killers',
#   '95e1ead9-4d31-4808-a7ac-32c3614c116b',
#   '4510073'],
#  [1,
#   'Taiwan',
#   20,
#   'Foo Fighters',
#   '67f66c07-6e61-4026-ade5-7e782fad3a5d',
#   '4066930'],
#  [1,
#   'Taiwan',
#   21,
#   'Arcade Fire',
#   '52074ba6-e495-4ef3-9bb4-0703888a9f68',
#   '2619181'],
#  [1,
#   'Taiwan',
#   22,
#   'Nine Inch Nails',
#   'b7ffd2af-418f-4be2-bdd1-22f8b48613da',
#   '2226945'],
#  [1,
#   'Taiwan',
#   23,
#   'The Cure',
#   '69ee3720-a7cb-4402-b48d-a02c366f2bcf',
#   '3013024'],
#  [1,
#   'Taiwan',
#   24,
#   'The Rolling Stones',
#   'b071f9fa-14b0-4217-8e97-eb41da73f598',
#   '3881095'],
#  [1,
#   'Taiwan',
#   25,
#   'Queens of the Stone Age',
#   '7dc8f5bd-9d0b-4087-9f73-dc164950bbd8',
#   '2525163'],
#  [1,
#   'Taiwan',
#   26,
#   'Pearl Jam',
#   '83b9cbe7-9857-49e2-ab8e-b57b01038103',
#   '2761999'],
#  [1,
#   'Taiwan',
#   27,
#   'The Doors',
#   '9efff43b-3b29-4082-824e-bc82f646f93d',
#   '3251433'],
#  [1,
#   'Taiwan',
#   28,
#   'Ed Sheeran',
#   'b8a7c51f-362c-4dcb-a259-bc6e0095f0a6',
#   '1771054'],
#  [1,
#   'Taiwan',
#   29,
#   'The Smashing Pumpkins',
#   'ba0d6274-db14-4ef5-b28d-657ebde1a396',
#   '2872922'],
#  [1,
#   'Taiwan',
#   30,
#   'Marilyn Manson',
#   '80cadd99-f560-41e3-babd-16292bbd248a',
#   '2278564'],
#  [1,
#   'Taiwan',
#   31,
#   'The White Stripes',
#   '11ae9fbb-f3d7-4a47-936f-4c0a04d3b3b5',
#   '3022360'],
#  [1,
#   'Taiwan',
#   32,
#   'The Weeknd',
#   'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#   '1402056'],
#  [1,
#   'Taiwan',
#   33,
#   'Weezer',
#   '6fe07aa5-fec0-4eca-a456-f29bff451b04',
#   '3122343'],
#  [1,
#   'Taiwan',
#   34,
#   'Black Sabbath',
#   '5182c1d9-c7d2-4dad-afa0-ccfeada921a8',
#   '2505045'],
#  [1,
#   'Taiwan',
#   35,
#   'David Guetta',
#   '302bd7b9-d012-4360-897a-93b00c855680',
#   '2866402'],
#  [1,
#   'Taiwan',
#   36,
#   'R.E.M.',
#   'ea4dfa26-f633-4da6-a52a-f49ea4897b58',
#   '2945551'],
#  [1,
#   'Taiwan',
#   37,
#   'Rage Against the Machine',
#   '3798b104-01cb-484c-a3b0-56adc6399b80',
#   '2898528'],
#  [1,
#   'Taiwan',
#   38,
#   'Beastie Boys',
#   '9beb62b2-88db-4cea-801e-162cd344ee53',
#   '2307573'],
#  [1,
#   'Taiwan',
#   39,
#   'Selena Gomez',
#   'e4bc69e2-a064-4f93-ada1-f7f209cc1cc3',
#   '1084598'],
#  [1,
#   'Taiwan',
#   40,
#   'Creedence Clearwater Revival',
#   '44c48a1b-defd-4222-bee6-03f9ee9a7be9',
#   '2428069'],
#  [1, 'Taiwan', 41, 'Dua Lipa', '', '618932'],
#  [1,
#   'Taiwan',
#   42,
#   'Disclosure',
#   'ae65c507-d9a0-4d42-9a6c-2b1f82158b9f',
#   '1043930'],
#  [1, 'Taiwan', 43, 'Future', '9f1195cf-9900-45db-bf9c-21c205672ae0', '764917'],
#  [1,
#   'Taiwan',
#   44,
#   'The Chainsmokers',
#   '91a81925-92f9-4fc9-b897-93cf01226282',
#   '889555'],
#  [1,
#   'Taiwan',
#   45,
#   'Paul McCartney',
#   'ba550d0e-adac-4864-b88b-407cab5e76af',
#   '1733542'],
#  [1,
#   'Taiwan',
#   46,
#   'Fatboy Slim',
#   'ba81eb4a-0c89-489f-9982-0154b8083a28',
#   '1967284'],
#  [1,
#   'Taiwan',
#   47,
#   'Lenny Kravitz',
#   '0ef3f425-9bd2-4216-9dd2-219d2fe90f1f',
#   '1834903'],
#  [1,
#   'Taiwan',
#   48,
#   'Charlie Puth',
#   '525f1f1c-03f0-4bc8-8dfd-e7521f87631b',
#   '551617'],
#  [1,
#   'Taiwan',
#   49,
#   'The Jackson 5',
#   'e5257dc5-1edd-4fca-b7e6-1158e00522c8',
#   '1580867'],
#  [1,
#   'Taiwan',
#   50,
#   'Rosalía',
#   'ac0ee862-a6ca-4d39-a7a4-d8460534ba30',
#   '212721'],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [None, None, None, None, None, None],
#  [3,
#   'Albania',
#   1,
#   'Coldplay',
#   'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#   '5487151'],
#  [3, 'Albania', 2, 'Queen', '420ca290-76c5-41af-999e-564d7c71f1a7', '4139663'],
#  [3,
#   'Albania',
#   3,
#   'David Bowie',
#   '5441c29d-3602-4898-b1a1-b77fa23b8e50',
#   '3443753'],
#  [3,
#   'Albania',
#   4,
#   'Radiohead',
#   'a74b1b7f-71a5-4011-9441-d0b5e4122711',
#   '4821534'],
#  [3,
#   'Albania',
#   5,
#   'Red Hot Chili Peppers',
#   '8bfac288-ccc5-448d-9573-c33ea2aa5c30',
#   '4704723'],
#  [3,
#   'Albania',
#   6,
#   'The Rolling Stones',
#   'b071f9fa-14b0-4217-8e97-eb41da73f598',
#   '3881095'],
#  [3,
#   'Albania',
#   7,
#   'Ed Sheeran',
#   'b8a7c51f-362c-4dcb-a259-bc6e0095f0a6',
#   '1771054'],
#  [3,
#   'Albania',
#   8,
#   'Metallica',
#   '65f4f0c5-ef9e-490c-aee3-909e7ae6b2ab',
#   '2960691'],
#  [3,
#   'Albania',
#   9,
#   'Nirvana',
#   '9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6',
#   '4362266'],
#  [3,
#   'Albania',
#   10,
#   'Led Zeppelin',
#   'd6e0e274-8e19-44ce-b5b2-52c12f8a674a',
#   '3010370'],
#  [3,
#   'Albania',
#   11,
#   'Arctic Monkeys',
#   'ada7a83c-e3e1-40f1-93f9-3e73dbc9298a',
#   '3594730'],
#  [3,
#   'Albania',
#   12,
#   'The Beatles',
#   'b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d',
#   '3783733'],
#  [3,
#   'Albania',
#   13,
#   'Pink Floyd',
#   '83d91898-7763-47d7-b03b-b92132375c47',
#   '3167698'],
#  [3,
#   'Albania',
#   14,
#   'Michael Jackson',
#   'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#   '3638749'],
#  [3,
#   'Albania',
#   15,
#   'Imagine Dragons',
#   '012151a8-0f9a-44c9-997f-ebd68b5389f9',
#   '1750734'],
#  [3, 'Albania', 16, 'Sia', '2f548675-008d-4332-876c-108b0c7ab9c5', '2214644'],
#  [3, 'Albania', 17, 'Muse', 'fd857293-5ab8-40de-b29e-55a69d4e4d0f', '4153641'],
#  [3, 'Albania', 18, 'U2', 'a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432', '3547039'],
#  [3,
#   'Albania',
#   19,
#   'Ellie Goulding',
#   '33ca19f4-18c8-4411-98df-ac23890ce9f5',
#   '2019315'],
#  [3,
#   'Albania',
#   20,
#   'Linkin Park',
#   'f59c5520-5f46-4d2c-b2c4-822eabf53419',
#   '4054402'],
#  [3,
#   'Albania',
#   21,
#   'The Weeknd',
#   'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#   '1402056'],
#  [3,
#   'Albania',
#   22,
#   'Lana Del Rey',
#   'b7539c32-53e7-4908-bda3-81449c367da6',
#   '2017109'],
#  [3,
#   'Albania',
#   23,
#   'The Killers',
#   '95e1ead9-4d31-4808-a7ac-32c3614c116b',
#   '4510073'],
#  [3,
#   'Albania',
#   24,
#   'Adele',
#   'cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493',
#   '2939437'],
#  [3,
#   'Albania',
#   25,
#   'David Guetta',
#   '302bd7b9-d012-4360-897a-93b00c855680',
#   '2866402'],
#  [3,
#   'Albania',
#   26,
#   'Fleetwood Mac',
#   'bd13909f-1c29-4c27-a874-d4aaf27c5b1a',
#   '2246300'],
#  [3,
#   'Albania',
#   27,
#   'Green Day',
#   '084308bd-1654-436f-ba03-df6697104e19',
#   '3827606'],
#  [3,
#   'Albania',
#   28,
#   'The Cure',
#   '69ee3720-a7cb-4402-b48d-a02c366f2bcf',
#   '3013024'],
#  [3,
#   'Albania',
#   29,
#   'AC/DC',
#   '66c662b6-6e2f-4930-8610-912e24c63ed1',
#   '2764236'],
#  [3,
#   'Albania',
#   30,
#   "Guns N' Roses",
#   'eeb1195b-f213-4ce1-b28c-8565211f8e43',
#   '3307648'],
#  [3,
#   'Albania',
#   31,
#   'Calvin Harris',
#   '8dd98bdc-80ec-4e93-8509-2f46bafc09a7',
#   '2292652'],
#  [3,
#   'Albania',
#   32,
#   'Frank Sinatra',
#   '197450cd-0124-4164-b723-3c22dd16494d',
#   '2454847'],
#  [3,
#   'Albania',
#   33,
#   'System of a Down',
#   'cc0b7089-c08d-4c10-b6b0-873582c17fd6',
#   '3556664'],
#  [3,
#   'Albania',
#   34,
#   'Florence + the Machine',
#   '5fee3020-513b-48c2-b1f7-4681b01db0c6',
#   '2483231'],
#  [3,
#   'Albania',
#   35,
#   'Maroon 5',
#   '0ab49580-c84f-44d4-875f-d83760ea2cfe',
#   '3609744'],
#  [3,
#   'Albania',
#   36,
#   'The Smashing Pumpkins',
#   'ba0d6274-db14-4ef5-b28d-657ebde1a396',
#   '2872922'],
#  [3,
#   'Albania',
#   37,
#   'Massive Attack',
#   '10adbe5e-a2c0-4bf3-8249-2b4cbf6e6ca8',
#   '2617141'],
#  [3, 'Albania', 38, 'Moby', '8970d868-0723-483b-a75b-51088913d3d4', '2700083'],
#  [3,
#   'Albania',
#   39,
#   'Eric Clapton',
#   '618b6900-0618-4f1e-b835-bccb17f84294',
#   '2462358'],
#  [3,
#   'Albania',
#   40,
#   'The xx',
#   'c5c2ea1c-4bde-4f4d-bd0b-47b200bf99d6',
#   '1974183'],
#  [3,
#   'Albania',
#   41,
#   'Rihanna',
#   'db36a76f-4cdf-43ac-8cd0-5e48092d2bae',
#   '4675544'],
#  [3,
#   'Albania',
#   42,
#   'The Doors',
#   '9efff43b-3b29-4082-824e-bc82f646f93d',
#   '3251433'],
#  [3,
#   'Albania',
#   43,
#   'The White Stripes',
#   '11ae9fbb-f3d7-4a47-936f-4c0a04d3b3b5',
#   '3022360'],
#  [3,
#   'Albania',
#   44,
#   'Amy Winehouse',
#   'dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3',
#   '2576338'],
#  [3,
#   'Albania',
#   45,
#   'Daft Punk',
#   '056e4f3e-d505-4dad-8ec1-d04f521cbb56',
#   '3864620'],
#  [3,
#   'Albania',
#   46,
#   'Bob Dylan',
#   '72c536dc-7137-4477-a521-567eeb840fa8',
#   '2726140'],
#  [3,
#   'Albania',
#   47,
#   'R.E.M.',
#   'ea4dfa26-f633-4da6-a52a-f49ea4897b58',
#   '2945551'],
#  [3, 'Albania', 48, 'Blur', 'ba853904-ae25-4ebb-89d6-c44cfbd71bd2', '2931347'],
#  [3,
#   'Albania',
#   49,
#   'Aretha Franklin',
#   '2f9ecbed-27be-40e6-abca-6de49d50299e',
#   '1804067'],
#  [3,
#   'Albania',
#   50,
#   'Gorillaz',
#   'e21857d5-3256-4547-afb3-4b6ded592596',
#   '3662829']]

# %%
df = pd.DataFrame.from_records(ListGeoTopArtists)

# %%
df
# Out:
#        0        1     2                        3  \
# 0    1.0   Taiwan   1.0              The Beatles
# 1    1.0   Taiwan   2.0                  Nirvana
# 2    1.0   Taiwan   3.0                Daft Punk
# 3    1.0   Taiwan   4.0                       U2
# 4    1.0   Taiwan   5.0                      Sia
# 5    1.0   Taiwan   6.0            Fleetwood Mac
# 6    1.0   Taiwan   7.0        Justin Timberlake
# 7    1.0   Taiwan   8.0               Elton John
# 8    1.0   Taiwan   9.0               The Police
# 9    1.0   Taiwan  10.0             Jason Derülo
# 10   1.0   Taiwan  11.0                  Cardi B
# 11   1.0   Taiwan  12.0           Arctic Monkeys
# 12   1.0   Taiwan  13.0                 Coldplay
# 13   1.0   Taiwan  14.0               Kanye West
# 14   1.0   Taiwan  15.0             Lana Del Rey
# 15   1.0   Taiwan  16.0    Red Hot Chili Peppers
# 16   1.0   Taiwan  17.0                   Eminem
# 17   1.0   Taiwan  18.0            Ariana Grande
# 18   1.0   Taiwan  19.0              The Killers
# 19   1.0   Taiwan  20.0             Foo Fighters
# 20   1.0   Taiwan  21.0              Arcade Fire
# 21   1.0   Taiwan  22.0          Nine Inch Nails
# 22   1.0   Taiwan  23.0                 The Cure
# 23   1.0   Taiwan  24.0       The Rolling Stones
# 24   1.0   Taiwan  25.0  Queens of the Stone Age
# 25   1.0   Taiwan  26.0                Pearl Jam
# 26   1.0   Taiwan  27.0                The Doors
# 27   1.0   Taiwan  28.0               Ed Sheeran
# 28   1.0   Taiwan  29.0    The Smashing Pumpkins
# 29   1.0   Taiwan  30.0           Marilyn Manson
# ..   ...      ...   ...                      ...
# 120  3.0  Albania  21.0               The Weeknd
# 121  3.0  Albania  22.0             Lana Del Rey
# 122  3.0  Albania  23.0              The Killers
# 123  3.0  Albania  24.0                    Adele
# 124  3.0  Albania  25.0             David Guetta
# 125  3.0  Albania  26.0            Fleetwood Mac
# 126  3.0  Albania  27.0                Green Day
# 127  3.0  Albania  28.0                 The Cure
# 128  3.0  Albania  29.0                    AC/DC
# 129  3.0  Albania  30.0            Guns N' Roses
# 130  3.0  Albania  31.0            Calvin Harris
# 131  3.0  Albania  32.0            Frank Sinatra
# 132  3.0  Albania  33.0         System of a Down
# 133  3.0  Albania  34.0   Florence + the Machine
# 134  3.0  Albania  35.0                 Maroon 5
# 135  3.0  Albania  36.0    The Smashing Pumpkins
# 136  3.0  Albania  37.0           Massive Attack
# 137  3.0  Albania  38.0                     Moby
# 138  3.0  Albania  39.0             Eric Clapton
# 139  3.0  Albania  40.0                   The xx
# 140  3.0  Albania  41.0                  Rihanna
# 141  3.0  Albania  42.0                The Doors
# 142  3.0  Albania  43.0        The White Stripes
# 143  3.0  Albania  44.0            Amy Winehouse
# 144  3.0  Albania  45.0                Daft Punk
# 145  3.0  Albania  46.0                Bob Dylan
# 146  3.0  Albania  47.0                   R.E.M.
# 147  3.0  Albania  48.0                     Blur
# 148  3.0  Albania  49.0          Aretha Franklin
# 149  3.0  Albania  50.0                 Gorillaz
#
#                                         4        5
# 0    b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d  3783733
# 1    9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  4362266
# 2    056e4f3e-d505-4dad-8ec1-d04f521cbb56  3864620
# 3    a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432  3547039
# 4    2f548675-008d-4332-876c-108b0c7ab9c5  2214644
# 5    bd13909f-1c29-4c27-a874-d4aaf27c5b1a  2246300
# 6    596ffa74-3d08-44ef-b113-765d43d12738  2894937
# 7    b83bc61f-8451-4a5d-8b8e-7e9ed295e822  2612368
# 8    9e0e2b01-41db-4008-bd8b-988977d6019a  2349324
# 9    6de0f914-3e60-4418-be3b-42e0feb6eb4d  1932949
# 10                                          402655
# 11   ada7a83c-e3e1-40f1-93f9-3e73dbc9298a  3594730
# 12   cc197bad-dc9c-440d-a5b5-d52ba2e14234  5487151
# 13   164f0d73-1234-4e2c-8743-d77bf2191051  4524008
# 14   b7539c32-53e7-4908-bda3-81449c367da6  2017109
# 15   8bfac288-ccc5-448d-9573-c33ea2aa5c30  4704723
# 16   b95ce3ff-3d05-4e87-9e01-c97b66af13d4  4624847
# 17   f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387  1239294
# 18   95e1ead9-4d31-4808-a7ac-32c3614c116b  4510073
# 19   67f66c07-6e61-4026-ade5-7e782fad3a5d  4066930
# 20   52074ba6-e495-4ef3-9bb4-0703888a9f68  2619181
# 21   b7ffd2af-418f-4be2-bdd1-22f8b48613da  2226945
# 22   69ee3720-a7cb-4402-b48d-a02c366f2bcf  3013024
# 23   b071f9fa-14b0-4217-8e97-eb41da73f598  3881095
# 24   7dc8f5bd-9d0b-4087-9f73-dc164950bbd8  2525163
# 25   83b9cbe7-9857-49e2-ab8e-b57b01038103  2761999
# 26   9efff43b-3b29-4082-824e-bc82f646f93d  3251433
# 27   b8a7c51f-362c-4dcb-a259-bc6e0095f0a6  1771054
# 28   ba0d6274-db14-4ef5-b28d-657ebde1a396  2872922
# 29   80cadd99-f560-41e3-babd-16292bbd248a  2278564
# ..                                    ...      ...
# 120  c8b03190-306c-4120-bb0b-6f2ebfc06ea9  1402056
# 121  b7539c32-53e7-4908-bda3-81449c367da6  2017109
# 122  95e1ead9-4d31-4808-a7ac-32c3614c116b  4510073
# 123  cc2c9c3c-b7bc-4b8b-84d8-4fbd8779e493  2939437
# 124  302bd7b9-d012-4360-897a-93b00c855680  2866402
# 125  bd13909f-1c29-4c27-a874-d4aaf27c5b1a  2246300
# 126  084308bd-1654-436f-ba03-df6697104e19  3827606
# 127  69ee3720-a7cb-4402-b48d-a02c366f2bcf  3013024
# 128  66c662b6-6e2f-4930-8610-912e24c63ed1  2764236
# 129  eeb1195b-f213-4ce1-b28c-8565211f8e43  3307648
# 130  8dd98bdc-80ec-4e93-8509-2f46bafc09a7  2292652
# 131  197450cd-0124-4164-b723-3c22dd16494d  2454847
# 132  cc0b7089-c08d-4c10-b6b0-873582c17fd6  3556664
# 133  5fee3020-513b-48c2-b1f7-4681b01db0c6  2483231
# 134  0ab49580-c84f-44d4-875f-d83760ea2cfe  3609744
# 135  ba0d6274-db14-4ef5-b28d-657ebde1a396  2872922
# 136  10adbe5e-a2c0-4bf3-8249-2b4cbf6e6ca8  2617141
# 137  8970d868-0723-483b-a75b-51088913d3d4  2700083
# 138  618b6900-0618-4f1e-b835-bccb17f84294  2462358
# 139  c5c2ea1c-4bde-4f4d-bd0b-47b200bf99d6  1974183
# 140  db36a76f-4cdf-43ac-8cd0-5e48092d2bae  4675544
# 141  9efff43b-3b29-4082-824e-bc82f646f93d  3251433
# 142  11ae9fbb-f3d7-4a47-936f-4c0a04d3b3b5  3022360
# 143  dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3  2576338
# 144  056e4f3e-d505-4dad-8ec1-d04f521cbb56  3864620
# 145  72c536dc-7137-4477-a521-567eeb840fa8  2726140
# 146  ea4dfa26-f633-4da6-a52a-f49ea4897b58  2945551
# 147  ba853904-ae25-4ebb-89d6-c44cfbd71bd2  2931347
# 148  2f9ecbed-27be-40e6-abca-6de49d50299e  1804067
# 149  e21857d5-3256-4547-afb3-4b6ded592596  3662829
#
# [150 rows x 6 columns]

# %%
df.iloc[50,:]
# Out:
# 0     NaN
# 1    None
# 2     NaN
# 3    None
# 4    None
# 5    None
# Name: 50, dtype: object

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
z = 1
for x in range(3):
    try:
        z = 1
        print(x)
        print(dwn.jsonlist[x]['topartists']['artist'][z]['name'])
    except:
        pass
# Out:
# 0
# Nirvana
# 1
# 2
# Queen

# %%
dwn.jsonlist[0]['topartists']['artist'][1]['name']
# Out:
# 'Nirvana'

# %%
# %%timeit
pd.read_json(json.dumps(dwn.jsonlist)).iloc[x,0]['artist'][z]['name']
# Out:
# 3.76 ms ± 118 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
dwn.jsonlist[x]['topartists']['artist'][z]['name']
# Out:
# 216 ns ± 66.8 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
LastFMLink(apikey).GeoGetTop(countries = countriesdf['CountryNameUrl'], method = 'artist')[57]
# Out:
# 'https://ws.audioscrobbler.com/2.0/?method=geo.gettopartists&limit=50&country=Czech+republic&api_key=24a6e38c235025362537c2bcd85e66d9&format=json'

# %% [markdown]
# STASH HERE

# %%
# LastFMLink object

class LastFMLink:
    '''
    LastFM object working with LastFM API accessible links. API key has to be provided.
    '''
    
    
    def __init__(self, apikey, format = 'json'):
        self.apikey = apikey
        self.limit = 50
        if format == 'json':
            self.format = 'json'
    
    
    def GeoGetTop(self, method = 'artist', countries = 'Czech+republic'):
        '''
        Obtain links containing info about most popular artists/tracks in given countries. 
        Countries: A list of country names, as defined by the ISO 3166-1 country names standard, multi-word names shall be seperated by '+'.
        Method: Either 'artist' or 'track' in order to obtain most popular artists or tracks in given countries.
        '''
        if method == 'artist':
            self.method = 'geo.gettopartists'
            if self.format == 'json':
                self.links = 'https://ws.audioscrobbler.com/2.0/?method=' + self.method + '&limit=' + str(self.limit) + '&country=' + countries + '&api_key=' + self.apikey + '&format=' + self.format
                return(self.links)
            
        elif method == 'track':
            self.method = 'geo.gettoptracks'
            if self.format == 'json':
                self.links = 'https://ws.audioscrobbler.com/2.0/?method=' + self.method + '&limit=' + str(self.limit) + '&country=' + countries + '&api_key=' + self.apikey + '&format=' + self.format
                return self.links  
            
        else:
            print('Choose either "artist" or "track" method, in order obtain most popular artists or tracks, respectively.')
    
    
    def ArtistGetInfo(self, artists = 'beach+house', autocorrect = 0):
        '''
        Obtain links containing info about given artists. Autocorrect transforms misspelled artist names into correct artist names, options are 1 for the enablement of autocorrect and 0 for otherwise.
        '''
        self.method = 'artist.getinfo'
        if self.format == 'json':
                self.links = 'https://ws.audioscrobbler.com/2.0/?method=' + self.method + '&limit=' + str(self.limit) + '&artist=' + artists + '&api_key=' + self.apikey + '&format=' + self.format + '&autocorrect=' + str(autocorrect)
                return self.links

# %%
last_fm_links = {'geo_top_artists': 0, 'geo_top_tracks': 0, 'artists_info': 0}

# %%
last_fm_links['geo_top_artists'] = LastFMLink(apikey).GeoGetTop(countries = countriesdf['CountryNameUrl'], method = 'artist')
last_fm_links['geo_top_tracks'] = LastFMLink(apikey).GeoGetTop(countries = countriesdf['CountryNameUrl'], method = 'track')

# %%
last_fm_links['artists_info'] = LastFMLink(apikey).ArtistGetInfo(artists = 'José+González')

# %%
LastFMLink(apikey).ArtistGetInfo(artists = '林俊傑')
# Out:
# 'https://ws.audioscrobbler.com/2.0/?method=artist.getinfo&limit=50&artist=林俊傑&api_key=24a6e38c235025362537c2bcd85e66d9&format=json&autocorrect=0'
